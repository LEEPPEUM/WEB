# %% [markdown]
# # 'utf-8'odec can't decode byte 0xba in position 2: invalid start byte

# %%
import pandas as pd
hs_code = pd.read_csv('./HScode.csv', encoding = 'ISO-8859-1')
hs_code
# Out:
#            HSºÎÈ£  Àû¿ë½ÃÀÛÀÏÀÚ  Àû¿ëÁ¾·áÀÏÀÚ  \
# 0       101211000      20130101      20201231
# 1       101219000      20120101      20201231
# 2       101291000      20120101      20201231
# 3       101299000      20120101      20201231
# 4       101301000      20130101      20201231
# ...           ...           ...           ...
# 13634  9704009000      20020101      20201231
# 13635  9705000000      20130101      20201231
# 13636  9706001000      20020101      20201231
# 13637  9706002000      20020101      20201231
# 13638  9706009000      20020101      20201231
#
#                                               ÇÑ±ÛÇ°¸ñ¸í  \
# 0                                            ³ó°¡ »çÀ°¿ë
# 1                                                   ±âÅ¸
# 2                                                 °æÁÖ¸»
# 3                                                   ±âÅ¸
# 4                                                 ¹ø½Ä¿ë
# ...                                                  ...
# ...

# %%
hs = hs_code.iloc[:,0]
hs
# Out:
# 0         101211000
# 1         101219000
# 2         101291000
# 3         101299000
# 4         101301000
#             ...
# 13634    9704009000
# 13635    9705000000
# 13636    9706001000
# 13637    9706002000
# 13638    9706009000
# Name: HSºÎÈ£, Length: 13639, dtype: int64

# %%
hs = hs.rename("HS_CODE")  # Series, not DataFrame
hs
# Out:
# 0         101211000
# 1         101219000
# 2         101291000
# 3         101299000
# 4         101301000
#             ...
# 13634    9704009000
# 13635    9705000000
# 13636    9706001000
# 13637    9706002000
# 13638    9706009000
# Name: HS_CODE, Length: 13639, dtype: int64

# %%
hs.to_csv('HS_CODE.csv')

# %%
len(hs)
# Out:
# 13639
